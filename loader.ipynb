# %%
# Introduction
import pandas as pd 
import numpy as np 
from db import create_table, insert_user, insert_product, insert_review

# %%
create_table()

# %%
users = pd.read_csv("./data/cleaned/user_table_processed.csv", encoding='latin1')
users.head(2)
# Out:
#                         user_id  product_id     user_name
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q  B07JW9H4J1         Manav
# 1  AHMY5CWJMMK5BJRBBSNLYT3ONILA  B07JW9H4J1  Adarsh gupta

# %%
for index,row in users.iterrows():
    id1 = row["user_id"]
    name1 = row["user_name"]
    insert_user(id1,name1)
# Out:
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ...
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id
# ERROR AL INSERTAR USUARIO -ERROR-: UNIQUE constraint failed: users.id

# %%
products = pd.read_csv("./data/cleaned/product_table_processed.csv", encoding='latin1')
products.head(2)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
#
#               category_1               category_2          category_3  \
# 0  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
# 1  Computers&Accessories  Accessories&Peripherals  Cables&Accessories
#
#   category_4 category_5  discounted_price  actual_price  discount_percentage  \
# 0     Cables  USBCables             399.0        1099.0                 0.64
# 1     Cables  USBCables             199.0         349.0                 0.43
#
#    rating  rating_count                                      about_product  \
# 0     4.2       24269.0  High Compatibility : Compatible With iPhone 12...
# 1     4.0       43994.0  Compatible with all Type C enabled devices, be...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...

# %%
for index, row in products.iterrows():
    product_id = row["product_id"]
    product_name = row["product_name"]
    category_1 = row["category_1"]
    category_2 = row["category_2"]
    category_3 = row["category_3"]
    category_4 = row["category_4"]
    category_5 = row["category_5"]
    discounted_price = row["discounted_price"]
    actual_price = row["actual_price"]
    discount_percentage = row["discount_percentage"]
    rating = row["rating"]
    rating_count = row["rating_count"]
    about_product = row["about_product"]
    img_link = row["img_link"]
    product_link = row["product_link"]
    insert_product(product_id,product_name,category_1,category_2,category_3,category_4,category_5,discounted_price,actual_price,discount_percentage,rating,rating_count,about_product,img_link,product_link)
# Out:
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id
# ERROR AL INSERTAR PRODUCT -ERROR-: UNIQUE constraint failed: products.id

# %%
review = pd.read_csv("./data/cleaned/review_table_processed.csv", encoding='latin1')
review.head(2)
# Out:
#    product_id                     user_id.1                     user_id.2  \
# 0  B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q  AHMY5CWJMMK5BJRBBSNLYT3ONILA
# 1  B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ  AGYYVPDD7YG7FYNBXNGXZJT525AQ
#
#                       user_id.3                     user_id.4  \
# 0  AHCTC6ULH4XB6YHDY6PCH2R772LQ  AGYHHIERNXKA6P5T7CZLXKVPT7IQ
# 1  AHONIZU3ICIEHQIGQ6R2VFRSBXOQ  AFPHD2CRPDZMWMBL7WXRSVYWS5JA
#
#                       user_id.5                     user_id.6  \
# 0  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q  AENGU523SXMOS7JPDTW52PNNVWGQ
# 1  AEZ346GX3HJ4O4XNRPHCNHXQURMQ  AEPSWFPNECKO34PUC7I56ITGXR6Q
#
#                       user_id.7                     user_id.8     review_id.1  \
# 0  AEQJHCVTNINBS4FKTBGQRQTGTE5Q  AFC3FFC5PKFF5PMA52S3VCHOZ5FQ  R3HXWT0LRP0NMF
# 1  AHWVEHR5DYLVFTO2KF3IZATFQSWQ  AH4QT33M55677I7ISQOAKEQWACYQ   RGIQEG07R9HS2
#
#    ... review_title_part_7                                review_title_part_8  \
# 0  ...        Good Product                               As of now seems good
# 1  ...            its good  Good quality for the price but one issue with ...
#
#                                review_content_part_1  \
# 0     Looks durable Charging is fine tooNo complains
# 1  I ordered this cable to connect my phone to An...
#
#                                review_content_part_2 review_content_part_3  \
# 0                            Charging is really fast         good product.
# 1  It quality is good at this price and the main ...       Value for money
#
#                   review_content_part_4  \
# 0  Till now satisfied with the quality.
# 1                   with extra length??
#
#                                review_content_part_5 review_content_part_6  \
# 0  This is a good product . The charging speed is...          Good quality
# 1                                               Good          working fine
#
#      review_content_part_7                              review_content_part_8
# 0          would recommend  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  Product quality is good  Good,  working fine, Product quality is good, ...
#
# [2 rows x 35 columns]

# %%
data = []

# Iterar sobre cada fila del DataFrame
for _, row in review.iterrows():
    review_product_id = row["product_id"]
    for i in range(1, 9):
        review_user_id = row[f"user_id.{i}"]
        review_id = row[f"review_id.{i}"]
        review_title = row[f"review_title_part_{i}"]
        review_content = row[f"review_content_part_{i}"]
        # Solo añadir si `user_id` y `user_name` no son nulos
        if pd.notna(review_user_id) and pd.notna(review_id) and pd.notna(review_title) and pd.notna(review_content):
            insert_review(id=review_id,id_user=review_user_id,id_product=review_product_id, title=review_title,content=review_content)
# Out:
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ...
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
# ERROR AL INSERTAR REVIEW -ERROR-: UNIQUE constraint failed: reviews.id
